# %% [markdown]
# # 2-Dimensional Boundaries

# %%
# %reload_ext autoreload

import numpy as np
import matplotlib.pyplot as plt
from stitch_boundaries import XStitchBoundary, TStitchBoundary

# %matplotlib inline

# %%
x_0 = -5
y_0 = 0
x_diff = 5
y_diff = 4
suture_len = 1
s_bound = XStitchBoundary(x_0, y_0, x_diff, y_diff, suture_len)
sutures = np.array(s_bound.sutures)

xy = sutures[:, 0]
uv = sutures[:, 1]
x = xy[:, 0]
y = xy[:, 1]
u = uv[:, 0]
v = uv[:, 1]

fig = plt.figure(figsize=(10,10))
plt.scatter(x, y, c='black')
plt.scatter(u, v, c='red')
plt.xticks(np.arange(-10,10,1))
plt.yticks(np.arange(-10,10,1))
plt.grid()
plt.show()
